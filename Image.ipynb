# %% [markdown]
# <a href="https://colab.research.google.com/github/Sambathmech/Portfolio/blob/main/Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2==3.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

# Open the PDF file in read-binary mode
with open('your_file.pdf', 'rb') as pdf_file:
    # Create a PDF reader object
    pdf_reader = PyPDF2.PdfReader(pdf_file)

    # Get the number of pages in the PDF
    num_pages = len(pdf_reader.pages)

    # Initialize an empty string to store the extracted text
    extracted_text = ''

    # Iterate over each page and extract the text
    for page_num in range(num_pages):
        page = pdf_reader.pages[page_num]
        extracted_text += page.extract_text()

# Print the extracted text
print(extracted_text)
# Out:
# RECREATION ROOMRECREATION ROOM
# RECREATION ROOMRECREATION
# ROOM 2
# RECREATION ROOM
# RECREATION ROOMRECREATION
# ROOM 2UNFINISHED STORAGE UNFINISHED STORAGE
# UNFINISHED STORAGE UNFINISHED STORAGE
# Southeast Zone
# 2475 Northwinds Pkwy, Suite 600
# Alpharetta, GA. 30009  (770) 381-3450
# Single Family
# Pulte
# Riverton
# 1853.200PLOTTED
# ©
# The RIVERTON
# 2.0.1
# 2.0.1 FINISH BASEMENT REAR OPTIONSBASEMENT W/ OPT. COVERED / SCREENED LANAI BASEMENT W/ OPT. 4' GATHERING ROOM EXT.
# BASEMENT W/ OPT. SUNROOM EXT. & OPT. COVERED / SCREENED LANAI
# BASEMENT W/ OPT. 4' GATHERING ROOM EXT. AND SUNROOMBASEMENT W/ OPT. 4' GATHERING ROOM
